# %% [markdown]
# # Kernel Density Estimation

# %% [markdown]
# - #### Quick notes/ research on KDEs, felt my course on data camp did not go into much depth.

# %% [markdown]
# https://www.youtube.com/watch?v=6sGOMbC5xdE
